# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг-1.-Загрузка-данных" data-toc-modified-id="Шаг-1.-Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг 1. Загрузка данных</a></span></li><li><span><a href="#Шаг-2.-Предобработка-данных" data-toc-modified-id="Шаг-2.-Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 2. Предобработка данных</a></span></li><li><span><a href="#Шаг-3.-Исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 3. Исследовательский анализ данных</a></span></li><li><span><a href="#3.1-Корреляционный-анализ" data-toc-modified-id="3.1-Корреляционный-анализ-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>3.1 Корреляционный анализ</a></span></li><li><span><a href="#Шаг-4.-Подготовка-данных" data-toc-modified-id="Шаг-4.-Подготовка-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг 4. Подготовка данных</a></span></li><li><span><a href="#Шаг-5.-Обучение-моделей" data-toc-modified-id="Шаг-5.-Обучение-моделей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Шаг 5. Обучение моделей</a></span></li><li><span><a href="#Шаг-6.-Промежуточный-вывод" data-toc-modified-id="Шаг-6.-Промежуточный-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Шаг 6. Промежуточный вывод</a></span></li><li><span><a href="#Шаг-1.-Загрузка-данных" data-toc-modified-id="Шаг-1.-Загрузка-данных-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Шаг 1. Загрузка данных</a></span></li><li><span><a href="#Шаг-2.-Предобработка-данных" data-toc-modified-id="Шаг-2.-Предобработка-данных-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Шаг 2. Предобработка данных</a></span></li><li><span><a href="#Шаг-3.-Исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Исследовательский-анализ-данных-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Шаг 3. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#3.1-Исследуем-все-признаки-новых-данных" data-toc-modified-id="3.1-Исследуем-все-признаки-новых-данных-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>3.1 Исследуем все признаки новых данных</a></span></li><li><span><a href="#3.2-Портрет-уволившегося-сотрудника" data-toc-modified-id="3.2-Портрет-уволившегося-сотрудника-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>3.2 Портрет уволившегося сотрудника</a></span></li><li><span><a href="#3.3-Влияет-ли-уровень-удовлетворенности-работой-сотрудника-на-его-увольнение" data-toc-modified-id="3.3-Влияет-ли-уровень-удовлетворенности-работой-сотрудника-на-его-увольнение-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>3.3 Влияет ли уровень удовлетворенности работой сотрудника на его увольнение</a></span></li></ul></li><li><span><a href="#Шаг-4.-Добавление-нового-входного-признака" data-toc-modified-id="Шаг-4.-Добавление-нового-входного-признака-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Шаг 4. Добавление нового входного признака</a></span></li><li><span><a href="#Шаг-5.-Подготовка-данных" data-toc-modified-id="Шаг-5.-Подготовка-данных-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Шаг 5. Подготовка данных</a></span></li><li><span><a href="#Шаг-6.-Обучение-модели" data-toc-modified-id="Шаг-6.-Обучение-модели-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Шаг 6. Обучение модели</a></span></li><li><span><a href="#Шаг-7.-Промежуточный-вывод" data-toc-modified-id="Шаг-7.-Промежуточный-вывод-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Шаг 7. Промежуточный вывод</a></span></li><li><span><a href="#Задача-№1" data-toc-modified-id="Задача-№1-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Задача №1</a></span><ul class="toc-item"><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-15.1"><span class="toc-item-num">15.1&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-15.2"><span class="toc-item-num">15.2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-15.3"><span class="toc-item-num">15.3&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение-модели" data-toc-modified-id="Обучение-модели-15.4"><span class="toc-item-num">15.4&nbsp;&nbsp;</span>Обучение модели</a></span></li></ul></li><li><span><a href="#Задача-№2" data-toc-modified-id="Задача-№2-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Задача №2</a></span><ul class="toc-item"><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-16.1"><span class="toc-item-num">16.1&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-16.2"><span class="toc-item-num">16.2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-16.3"><span class="toc-item-num">16.3&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение-модели" data-toc-modified-id="Обучение-модели-16.4"><span class="toc-item-num">16.4&nbsp;&nbsp;</span>Обучение модели</a></span></li></ul></li></ul></div>

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# # Описание задачи
#
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
#
#
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.
#
#
# У нас будет несколько задач:
# 1. Построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика:
#     - удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
# 2. Построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# # Описание данных
#
# Для этой задачи заказчик предоставил данные с признаками:
# - `id` — уникальный идентификатор сотрудника;
#
# - `dept` — отдел, в котором работает сотрудник;
# - `level` — уровень занимаемой должности;
# - `workload` — уровень загруженности сотрудника;
# - `employment_years` — длительность работы в компании (в годах);
# - `last_year_promo` — показывает, было ли повышение за последний год;
# - `last_year_violations` — показывает, нарушал ли сотрудник трудовой договор за последний год;
# - `supervisor_evaluation` — оценка качества работы сотрудника, которую дал руководитель;
# - `salary` — ежемесячная зарплата сотрудника;
# - `job_satisfaction_rate` — уровень удовлетворённости сотрудника работой в компании, целевой признак первой задачи;
# - `quit` — увольнение сотрудника из компании.

# %% [markdown]
# Установим необходимые библиотеки

# %%
# !pip install -U scikit-learn

# %%
# !pip install phik

# %%
# Импортируем библиотеки
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats as st

from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import roc_auc_score, make_scorer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.dummy import DummyRegressor, DummyClassifier

from phik import phik_matrix
from phik.report import plot_correlation_matrix

import warnings

# Отключим предупреждения и установим стиль для графиков
warnings.filterwarnings('ignore')
sns.set_style('darkgrid')

# %% [markdown]
# Установим константу для псевдорандомной генерации

# %%
RANDOM_STATE = 42

# %% [markdown]
# # Задача 1: предсказание уровня удовлетворённости сотрудника

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %% [markdown]
# Загрузим файлы

# %%
try:
    train_sat = pd.read_csv(r"C:\Users\ilyal\OneDrive\Рабочий стол\Портфолио\practicum_projects\work_with_care_8\train_job_satisfaction_rate.csv")
    test_target_sat = pd.read_csv(r"C:\Users\ilyal\OneDrive\Рабочий стол\Портфолио\practicum_projects\work_with_care_8\test_target_job_satisfaction_rate.csv")
    test_features = pd.read_csv(r"C:\Users\ilyal\OneDrive\Рабочий стол\Портфолио\practicum_projects\work_with_care_8\test_features.csv")
    
except:
    train_sat = pd.read_csv(r'/datasets/train_job_satisfaction_rate.csv')
    test_target_sat = pd.read_csv(r'/datasets/test_target_job_satisfaction_rate.csv')
    test_features = pd.read_csv(r'/datasets/test_features.csv')

# %%
train_sat.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20

# %%
test_target_sat.head()
# Out:
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %%
test_features.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
# Данные успешно загружены.

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# Функция для вывода общей информации о датафрейме

# %%
def information(df, name):
    print(f'Общая информация о датафрейме {name}\n')
    display(df.info())
    display(df.head())
    print(f'Количество явных дубликатов:')
    display(df.duplicated().sum())

# %% [markdown]
# Фукнция для вывода уникальных значений строковых столбцов

# %%
def unique_object(df, name):
    print(f'Датафрейм: {name}\n')
    for col in df.columns:
        if df[col].dtype == 'object':
            unique_vals = df[col].unique()
            print(f'Уникальные значения столбца {col}: {unique_vals}')

# %% [markdown]
# Функция для подсчета уникальных значений в столбцах

# %%
def count_of_values(df, name):
    print(f'Датафрейм: {name}\n')
    for col in df.columns:
        if col != 'id' and len(df[col].unique()) <= 8:
            print(df[col].value_counts())
            print()

# %% [markdown]
# Датафрейм **train_sat**

# %%
information(train_sat, 'Train satisfaction rate')
# Out:
# Общая информация о датафрейме Train satisfaction rate
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB
# None
#        id        dept   level workload  employment_years last_year_promo  \
# ...

# %% [markdown]
# Количество значений в столбцах

# %%
count_of_values(train_sat, 'Train sat')
# Out:
# Датафрейм: Train sat
#
# dept
# sales         1512
# technology     866
# purchasing     610
# marketing      550
# hr             456
# Name: count, dtype: int64
#
# level
# junior    1894
# middle    1744
# sinior     358
# Name: count, dtype: int64
#
# workload
# medium    2066
# low       1200
# high       734
# Name: count, dtype: int64
#
# last_year_promo
# no     3880
# yes     120
# Name: count, dtype: int64
#
# last_year_violations
# no     3441
# yes     559
# Name: count, dtype: int64
#
# supervisor_evaluation
# 4    1603
# 3    1263
# 5     546
# 2     387
# 1     201
# Name: count, dtype: int64

# %% [markdown]
# Уникальные строковые значения

# %%
unique_object(train_sat, 'Train sat')
# Out:
# Датафрейм: Train sat
#
# Уникальные значения столбца dept: ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan]
# Уникальные значения столбца level: ['junior' 'middle' 'sinior' nan]
# Уникальные значения столбца workload: ['medium' 'high' 'low']
# Уникальные значения столбца last_year_promo: ['no' 'yes']
# Уникальные значения столбца last_year_violations: ['no' 'yes']

# %% [markdown]
# Переименуем `sinior` на `senior`

# %%
train_sat['level'] = train_sat['level'].replace({'sinior': 'senior'})

# %%
train_sat['level'].value_counts()
# Out:
# level
# junior    1894
# middle    1744
# senior     358
# Name: count, dtype: int64

# %% [markdown]
# Преобразование прошло успешно.

# %% [markdown]
# ---

# %% [markdown]
# Датафрейм **test_features**

# %%
information(test_features, 'Test features')
# Out:
# Общая информация о датафрейме Test features
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
# None
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# ...

# %%
count_of_values(test_features, 'Test features')
# Out:
# Датафрейм: Test features
#
# dept
# sales         763
# technology    455
# marketing     279
# purchasing    273
# hr            227
#                 1
# Name: count, dtype: int64
#
# level
# junior    974
# middle    854
# sinior    171
# Name: count, dtype: int64
#
# workload
# medium    1043
# low        593
# high       363
#              1
# Name: count, dtype: int64
#
# last_year_promo
# no     1937
# yes      63
# Name: count, dtype: int64
#
# last_year_violations
# no     1738
# yes     262
# Name: count, dtype: int64
#
# supervisor_evaluation
# 4    857
# 3    575
# 5    284
# 2    196
# 1     88
# Name: count, dtype: int64

# %%
unique_object(test_features, 'Test features')
# Out:
# Датафрейм: Test features
#
# Уникальные значения столбца dept: ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
# Уникальные значения столбца level: ['junior' 'middle' 'sinior' nan]
# Уникальные значения столбца workload: ['medium' 'low' 'high' ' ']
# Уникальные значения столбца last_year_promo: ['no' 'yes']
# Уникальные значения столбца last_year_violations: ['no' 'yes']

# %% [markdown]
# Переименуем так же `sinior` и заменим пустую строку на `np.nan`

# %%
test_features['level'] = test_features['level'].replace({'sinior': 'senior'})
test_features['dept'] = test_features['dept'].replace({' ': np.nan})
test_features['workload'] = test_features['workload'].replace({' ': np.nan})

# %% [markdown]
# Преобразование прошло успешно.

# %% [markdown]
# ---

# %% [markdown]
# Датафрейм **test_target_sat**

# %%
information(test_target_sat, 'Test target sat')
# Out:
# Общая информация о датафрейме Test target sat
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
# None
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08
# Количество явных дубликатов:
# 0

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# **Была проведена предобработка данных:**
#
# - изменена орфография;
#
# - строки состоящие из пробелов были заменены на пропуски.
#
# В некоторых столбцах есть пропуски. Заполним их на этапе построения пайплайна с помощью **SimpleImputer**

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# Построим гистограммы и коробки с усами для числовых значений. Для категориальных столбцов будем строить диаграммы накопления.

# %% [markdown]
# Датафрейм **train_sat**

# %% [markdown]
# Построение гистограмм:

# %%
hist_cols = ['salary', 'job_satisfaction_rate']

plt.figure(figsize=(15, 6))
for i, col in enumerate(hist_cols, 1):
    plt.subplot(1, 3, i) 
    sns.histplot(data=train_sat, x=col, color='skyblue')
    plt.title(col.capitalize(), fontsize=15)
    plt.xlabel('')
    plt.ylabel('Количество')
    plt.grid(axis='y', linestyle='--', linewidth=0.5)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Построение ящиков с усами:

# %%
# Создание фигуры
plt.figure(figsize=(12, 10))

# Цикл для построения графиков
for i, col in enumerate(hist_cols, 1):
    plt.subplot(4, 2, i)
    sns.boxplot(x=col, data=train_sat)
    plt.title(col.capitalize(), fontsize=15, pad=15)
    plt.xlabel('')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Выводы по гистограммам и коробкам с усами:**
#
# - распределение зарплаты скошено вправо. В среднем значение около 30 тысяч рублей. Максимальная зарплата 98400
#
# - распределение целевого признака равномерное. Наблюдаются пики в значениях 0.7 и 0.35

# %% [markdown]
# Построим диаграммы накопления для категориальных столбцов:

# %%
bar_cols = ['dept', 'level', 'workload',
            'last_year_promo', 'last_year_violations',
            'supervisor_evaluation', 'employment_years']

plt.figure(figsize=(12, 10))

for i, col in enumerate(bar_cols, 1):
    plt.subplot(3, 3, i)
    sns.barplot(x=train_sat[col].value_counts().index, y=train_sat[col].value_counts())
    plt.title(col.capitalize(), fontsize=15)
    plt.xlabel('')
    plt.ylabel('Количество')
    plt.xticks(rotation=20)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод по barplot:**
#
# - Самое большое количество сотрудников работает в отделе продаж. На втором месте отдел технологий. На третьем отдел покупок
#
# - Сотрудников уровня `junior` и `middle` поровну, а уровня `senior` в разы меньше
#
# - Большая часть сотрудников загружена средне
#
# - Всего 3% сотрудников получали повышение в последнем году
#
# - 16% сотрудников нарушали условия трудового договора за последний год
#
# - Начальник чаще всего ставит оценки `хорошо` и `удовлетворительно`
#
# - Большая часть сотрудников проработала в компании меньше 4-х лет

# %% [markdown]
# Датафрейм **test_features**

# %% [markdown]
# Построение гистограм:

# %%
plt.figure(figsize=(15, 6))

sns.histplot(data=test_features, x='salary', color='skyblue', bins=18)
plt.title('Salary', fontsize=15)
plt.xlabel('')
plt.ylabel('Количество')
plt.grid(axis='y', linestyle='--', linewidth=0.5)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Построение ящиков с усами:

# %%
sns.boxplot(x='salary', data=test_features)
plt.title('Salary', fontsize=15, pad=15)
plt.xlabel('')
    
plt.show()

# %% [markdown]
# Построение диаграмм накопления для категориальных столбцов:

# %%
bar_cols = ['dept', 'level', 'workload',
            'last_year_promo', 'last_year_violations',
            'supervisor_evaluation', 'employment_years']

plt.figure(figsize=(12, 8))

for i, col in enumerate(bar_cols, 1):
    plt.subplot(2, 4, i)
    sns.barplot(x=test_features[col].value_counts().index, y=test_features[col].value_counts(normalize=True))
    plt.title(col.capitalize(), fontsize=15)
    plt.xlabel('')
    plt.ylabel('Проценты')
    plt.xticks(rotation=20)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Выводы:**
#
# - Гистограммы тестовых данных не различаются с тренировочными, соотношение примерно одинаковое

# %% [markdown]
# Датафрейм **test_target_sat**

# %% [markdown]
# Построим гистограмму для целевого признака:

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data=test_target_sat, x='job_satisfaction_rate', color='skyblue')
plt.title('Распределение целевого признака тестовой выборки')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# ## 3.1 Корреляционный анализ

# %% [markdown]
# Датафрейм **train_sat**

# %%
interval_cols = ['salary', 'job_satisfaction_rate']

# %%
t = train_sat.drop('id', axis=1)

phik_overview = phik_matrix(t, interval_cols=interval_cols)

# %%
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(15, 10)
)

# %% [markdown]
# **Вывод по матрице корреляций:**
#
# - с целевым признаком достаточно сильно коррелирует оценка сотрудника руководителем и наличие нарушений за последний год
#
# - зарплата коррелирует с уровнем сотрудника и его загруженность
#
# - в свою очередь с уровнем сотрудника коррелирует количество отработанных лет и загруженность

# %% [markdown]
# ---

# %% [markdown]
# Датафрейм **test_features**

# %%
interval_cols = ['salary']

t = test_features.drop('id', axis=1)

phik_overview = phik_matrix(t, interval_cols=interval_cols)

# %%
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(15, 10)
)

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# **Выводы:**
# - распределение количества отработанных лет в компании выглядит логичным. Большинство сотрудников проработали в компании менее 4 лет. Медианное время - 3 года
#
# - распределение зарплаты скошено вправо. В среднем значение около 30 тысяч рублей. Максимальная зарплата 98400
#
# - распределение целевого признака равномерное. Наблюдаются пики в значениях 0.7 и 0.35
#
# - Самое большое количество сотрудников работает в отделе продаж. На втором месте отдел технологий. На третьем отдел покупок
#
# - Сотрудников уровня `junior` и `middle` поровну, а уровня `senior` в разы меньше
#
# - Большая часть сотрудников загружена средне
#
# - Всего 3% сотрудников получали повышение в последнем году
#
# - 16% сотрудников нарушали условия трудового договора за последний год
#
# - Начальник чаще всего ставит оценки `хорошо` и `удовлетворительно`
#
# - Гистограммы тестовых данных не различаются с тренировочными, соотношение примерно одинаковое
# - Распределение целевого признака тестовых данных такое же как и на тренировочных.
#
# **Вывод по матрице корреляций:**
#
# - с целевым признаком достаточно сильно коррелирует оценка сотрудника руководителем и наличие нарушений за последний год
#
# - зарплата коррелирует с уровнем сотрудника и его загруженность
#
# - в свою очередь с уровнем сотрудника коррелирует количество отработанных лет и загруженность

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 4. Подготовка данных

# %% [markdown]
# Создадим списки с названиями столбцов для обработки

# %%
# Категориальные столбцы без определенного порядка
cat_cols = ['dept', 'last_year_promo', 'last_year_violations', 'supervisor_evaluation']

# Категориальные столбцы с определенным порядком
ord_cols = ['level', 'workload']

# Числовые столбцы
num_cols = ['salary', 'employment_years']

# %% [markdown]
# Отсортируем тестовую выборку по значению `id`

# %%
test_features_sorted = test_features.sort_values('id')

# %%
test_target_sat_sorted = test_target_sat.sort_values('id')

# %% [markdown]
# ---

# %% [markdown]
# Создадим пайплайны

# %% [markdown]
# Пайплайн для кодирования категориальных признаков без ранжирования

# %%
ohe_pipe = Pipeline([
    ('imputing', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
    ('ohe', OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'))
])

# %% [markdown]
# Пайплайн для кодирования категориальных признаков с ранжированием

# %%
ord_pipe = Pipeline([
    ('impute_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')
    ),
    
    ('ord',OrdinalEncoder(
        categories=[
            ['junior', 'middle', 'senior'],
            ['low', 'medium', 'high']
        ],
        handle_unknown='use_encoded_value',
        unknown_value=np.nan)
    ),
    
    ('impute_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')
    )]
)

# %% [markdown]
# Преобразование столбцов

# %%
data_preprocessor = ColumnTransformer([
    ('ohe', ohe_pipe, cat_cols),
    ('ord', ord_pipe, ord_cols),
    ('num', StandardScaler(), num_cols)],
    remainder='passthrough'
)

# %% [markdown]
# Создание финального пайплайна

# %%
pipe_final = Pipeline(
    [
        ('preprocessor',data_preprocessor),
        ('models', LinearRegression())
    ]
)

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 5. Обучение моделей

# %% [markdown]
# Нам необходимо создать функцию, которая рассчитывает метрику SMAPE.

# %% [markdown]
# Создание функции:

# %%
def SMAPE(y_true, y_pred):
    return np.mean(
        np.abs(y_true - y_pred)/
            ((np.abs(y_true) + np.abs(y_pred))/2)
                  )*100
 
scorer = make_scorer(SMAPE, greater_is_better=False)

# %% [markdown]
# Создадим сетку для перебора моделей и их гиперпараметров

# %%
param_grid = [
    {
        'models': [LinearRegression()],
        'models__n_jobs': [-1],
        'preprocessor__num': [MinMaxScaler(), StandardScaler(), 'passthrough']
    },
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__min_samples_split': range(2, 20),
        'models__min_samples_leaf': range(2, 20),
        'preprocessor__num': [MinMaxScaler(), StandardScaler(), 'passthrough']
    }
]

# %% [markdown]
# Перебирать комбинации будем с помощью `RandomizedSearchCV`

# %% [markdown]
# В качестве метрики укажем SMAPE

# %%
randomized_search = RandomizedSearchCV(
    pipe_final,
    param_grid,
    cv=5,
    scoring=scorer,
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# %% [markdown]
# Обучим модель на тренировочных данных.

# %%
randomized_search.fit(train_sat.drop(['id', 'job_satisfaction_rate'], axis=1), train_sat['job_satisfaction_rate'])
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('imputing',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %%
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели при кросс-валидации:', abs(randomized_search.best_score_))
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('imputing',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['dept', 'last_year_promo',
#                                                    'last_year_violations',
# ...

# %% [markdown]
# Лучшей моделью оказался `DecisionTreeRegressor` с метрикой при кросс-валидации **14.6**

# %% [markdown]
# Вытащим лучшую модель из пайплайна и сделаем предсказание на тестовой выборке

# %%
best_model_sat = randomized_search.best_estimator_
y_pred = best_model_sat.predict(test_features_sorted)

# %% [markdown]
# Рассчитаем метрику SMAPE

# %%
smape = SMAPE(test_target_sat_sorted['job_satisfaction_rate'], y_pred)
print(f'Метрика SMAPE на тестовой выборке: {smape}')
# Out:
# Метрика SMAPE на тестовой выборке: 13.878070846062013

# %% [markdown]
# Проверим нашу модель на адекватность и пригодность к использованию

# %% [markdown]
# Для этого будем использовать константные предсказания с помощью `DummyRegressor`. Стратегия - среднее значение

# %%
train_sat_preprocessed = pipe_final.named_steps['preprocessor'].fit_transform(train_sat.drop(
    ['id', 'job_satisfaction_rate'], axis=1))
test_features_preprocessed = pipe_final.named_steps['preprocessor'].transform(test_features.drop(
    ['id'], axis=1))

feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()

train_sat_preprocessed = pd.DataFrame(train_sat_preprocessed, columns=feature_names)
test_features_preprocessed = pd.DataFrame(test_features_preprocessed, columns=feature_names)

dummy_regressor = DummyRegressor(strategy='mean')
dummy_regressor.fit(train_sat_preprocessed, train_sat['job_satisfaction_rate'])

dummy_pred = dummy_regressor.predict(test_features_preprocessed)

smape = SMAPE(test_target_sat_sorted['job_satisfaction_rate'], dummy_pred)
print(f'Метрика SMAPE на тренировочных данных с помощью константной моделью: {smape}')
# Out:
# Метрика SMAPE на тренировочных данных с помощью константной моделью: 38.21941812666904

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 6. Промежуточный вывод

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# **Вывод:**
#
# - был построен пайплайн с обработкой данных. Для кодирования использовались `OneHotEncoder`и `OrdinalEncoder`. Для масштабирования были использованы `MinMaxScaler` и `StandardScaler`
#
# - была создана функция для рассчета метрики SMAPE
#
# - лучшей моделью оказался `DecisionTreeRegressor` с метрикой на тренировочной выборке при кросс-валидации **14.6**
#
# - на тестовых данных метрика равна **13.8**
#
# - модель была проверена на адекватность с помощью DummyRegressor. Метрика при предсказании средним - **38.2**
#
#
# Модель дерева решений справилась лучше, так как обладает более тонкой настройкой, из чего следует, что такая модель умеет улавливать более сложные зависимости, нежели простая Линейная регрессия.

# %% [markdown]
# ---

# %% [markdown]
# # Задача 2: предсказание увольнения сотрудника из компании
# Для этой задачи мы можем использовать те же входные признаки, что и в предыдущей задаче. Однако целевой признак отличается: это `quit` — увольнение сотрудника из компании.

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %%
try:
    train_quit = pd.read_csv(r"C:\Users\ilyal\OneDrive\Рабочий стол\Портфолио\practicum_projects\work_with_care_8\train_quit.csv")
    test_target_quit = pd.read_csv(r"C:\Users\ilyal\OneDrive\Рабочий стол\Портфолио\practicum_projects\work_with_care_8\test_target_quit.csv")
    
except:
    train_quit = pd.read_csv(r'/datasets/train_quit.csv')
    test_target_quit = pd.read_csv(r'/datasets/test_target_quit.csv')

# %%
train_quit.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no

# %%
test_target_quit.head()
# Out:
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes

# %% [markdown]
# Данные загружены успешно.

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# Выведем основную информацию о датафреймах,

# %% [markdown]
# Датафрейм **train_quit**

# %%
information(train_quit, 'Train quit')
# Out:
# Общая информация о датафрейме Train quit
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
# None
#        id        dept   level workload  employment_years last_year_promo  \
# ...

# %%
count_of_values(train_quit, 'Train quit')
# Out:
# Датафрейм: Train quit
#
# dept
# sales         1438
# technology     928
# purchasing     588
# marketing      582
# hr             464
# Name: count, dtype: int64
#
# level
# junior    1949
# middle    1694
# sinior     357
# Name: count, dtype: int64
#
# workload
# medium    2118
# low       1208
# high       674
# Name: count, dtype: int64
#
# last_year_promo
# no     3887
# yes     113
# Name: count, dtype: int64
#
# last_year_violations
# no     3455
# yes     545
# Name: count, dtype: int64
#
# supervisor_evaluation
# 4    1654
# 3    1233
# 5     520
# 2     391
# 1     202
# Name: count, dtype: int64
#
# quit
# no     2872
# yes    1128
# Name: count, dtype: int64

# %%
unique_object(train_quit, 'Train quit')
# Out:
# Датафрейм: Train quit
#
# Уникальные значения столбца dept: ['sales' 'purchasing' 'marketing' 'technology' 'hr']
# Уникальные значения столбца level: ['middle' 'junior' 'sinior']
# Уникальные значения столбца workload: ['high' 'medium' 'low']
# Уникальные значения столбца last_year_promo: ['no' 'yes']
# Уникальные значения столбца last_year_violations: ['no' 'yes']
# Уникальные значения столбца quit: ['no' 'yes']

# %% [markdown]
# ---

# %% [markdown]
# Датафрейм **test_target_quit**

# %%
test_target_quit.sample(10)
# Out:
#           id quit
# 26    173430   no
# 221   477684  yes
# 546   752859  yes
# 552   454520  yes
# 284   189647   no
# 730   367507   no
# 266   934038   no
# 729   976183   no
# 1770  554729   no
# 1811  445909  yes

# %% [markdown]
# ---

# %% [markdown]
# Заменим орфографию

# %%
train_quit['level'] = train_quit['level'].replace({'sinior': 'senior'})

# %% [markdown]
# Отсортируем значения тестовой выборки по `id`

# %%
test_features_sorted_new = test_features.sort_values(by='id')
test_target_quit_sorted = test_target_quit.sort_values(by='id')

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# **Выводы:**
#
# Была проведена предобработка данных:
#
# - исправлена орфография;
#
# - строковой целевой признак был заменен на числовые категории;
#
# - тестовая выборка отсортирована по `id`

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ### 3.1 Исследуем все признаки новых данных

# %% [markdown]
# Построение гистограмм для числовых столбцов

# %%
plt.figure(figsize=(12, 4))

sns.histplot(data=train_quit, x='salary', color='skyblue')
plt.title('Salary', fontsize=15)
plt.xlabel('')
plt.ylabel('Количество')
plt.grid(axis='y', linestyle='--', linewidth=0.5)
    
plt.show()

# %%
# Создание фигуры
plt.figure(figsize=(8, 4))

sns.boxplot(x='salary', data=train_quit)
plt.title('Salary', fontsize=15, pad=15)
plt.xlabel('')

plt.show()

# %% [markdown]
# Выводы по гистограммам и ящикам с усами:
#
# - распределение зарплаты скошено вправо. 75% сотрудников получают менее 75000

# %% [markdown]
# Построение диаграмм накопления:

# %%
bar_cols = ['dept', 'level', 'workload',
            'last_year_promo', 'last_year_violations',
            'supervisor_evaluation','employment_years', 'quit']

plt.figure(figsize=(12, 10))

for i, col in enumerate(bar_cols, 1):
    plt.subplot(3, 4, i)
    sns.barplot(x=train_quit[col].value_counts().index, y=train_quit[col].value_counts())
    plt.title(col.capitalize(), fontsize=15)
    plt.xlabel('')
    plt.ylabel('Количество')
    plt.xticks(rotation=20)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Проведем корреляционный анализ. Так как в данных есть категориальные данные, то будем использовать корреляцию Фика

# %%
interval_cols = ['employment_years', 'salary']

t = train_quit.drop('id', axis=1)

phik_overview = phik_matrix(t, interval_cols=interval_cols)

# %%
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(15, 10)
)

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# **Вывод:**
#
# - распределение отработанных в кампании лет выглядит логичным. Большинство сотрудников отработали 3 и менее года
#
# - распределение зарплаты скошено вправо. 75% сотрудников получают менее 75000
#
# - топ-3 по популярности отделов выглядит так: Отдел продаж, отдел разработки, отдел закупок
#
# - больше всего в компании сотрудников уровня `junior` и `middle`, `senior` намного меньше
#
# - большинство сотрудников имеют среднюю загруженность
#
# - больше 90% сотрудников не получали повышение за последний год
#
# - примерно 15% сотрудников нарушали условия трудового договора за последний год
#
# - чаще всего руководитель оценивает работу сотрудников на 4, чуть реже на 3
#
# - примерно 1/3 сотрудников покинуло компанию
#
# - с целевым признаком сильнее всего коррелируют количество отработанных в кампании лет и зарплата.

# %% [markdown]
# ### 3.2 Портрет уволившегося сотрудника

# %% [markdown]
# Сохраним данные только об уволившихся сотрудниках

# %%
df_quit = train_quit[train_quit['quit'] == 'yes']
df_no_quit = train_quit[train_quit['quit'] == 'no']
df_quit.head()
# Out:
#         id        dept   level workload  employment_years last_year_promo  \
# 3   257132       sales  junior   medium                 2              no
# 5   699916       sales  junior      low                 1              no
# 9   613206  technology  middle   medium                 2              no
# 24  468145  technology  junior   medium                 2              no
# 25  982346   marketing  junior   medium                 3              no
#
#    last_year_violations  supervisor_evaluation  salary quit
# 3                   yes                      3   24000  yes
# 5                   yes                      3   18000  yes
# 9                    no                      3   45600  yes
# 24                   no                      3   30000  yes
# 25                   no                      3   30000  yes

# %% [markdown]
# Построим всё те же графики

# %% [markdown]
# Построение гистограмм:

# %%
plt.figure(figsize=(12, 4))

plt.subplot(2, 2, 1)
sns.histplot(x=df_quit['salary'], color='skyblue')
plt.title('Зарплата уволившихся сотрудников', fontsize=15)
plt.xlabel('')
plt.ylabel('Количество')

plt.subplot(2, 2, 2)
sns.boxplot(x=df_quit['salary'], color='skyblue')
plt.title('Salary', fontsize=15)
plt.xlabel('')


plt.subplot(2, 2, 3)
sns.histplot(x=df_no_quit['salary'], color='Red')
plt.title('Зарплата остальных сотрудников', fontsize=15)
plt.xlabel('')
plt.ylabel('Количество')

plt.subplot(2, 2, 4)
sns.boxplot(x=df_no_quit['salary'], color='Red')
plt.title('Salary', fontsize=15)
plt.xlabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# Сравним основные статистики для уволившихся сотруников и всех остальных

# %%
print('Уволившиеся сотрудники')
display(df_quit.describe())
print('Остальные сотрудники')
display(df_no_quit.describe())
# Out:
# Уволившиеся сотрудники
#                   id  employment_years  supervisor_evaluation        salary
# count    1128.000000       1128.000000            1128.000000   1128.000000
# mean   544544.457447          1.844858               3.046099  23885.106383
# std    258059.498361          1.274920               0.973291   9351.599505
# min    100222.000000          1.000000               1.000000  12000.000000
# 25%    325073.000000          1.000000               3.000000  16800.000000
# 50%    545003.500000          1.000000               3.000000  22800.000000
# 75%    756296.000000          2.000000               4.000000  27600.000000
# max    999158.000000         10.000000               5.000000  79200.000000
# Остальные сотрудники
#                   id  employment_years  supervisor_evaluation        salary
# count    2872.000000       2872.000000            2872.000000   2872.000000
# mean   555066.499652          4.430710               3.643106  37702.228412
# ...

# %% [markdown]
# **Вывод:**
#
# - в большинстве случаев увольнялись сотрудники со стажем работы мене 2х лет
#
# - средняя зарплата таких сотрудников от 20-25 тысяч. ***((неудивительно))***
#
# - средняя же зарплата остальных сотрудников значительно выше и составляет 37-40 тысяч.

# %% [markdown]
# Построение диаграмм накопления:

# %%
bar_cols = ['dept', 'level', 'workload',
            'last_year_promo', 'last_year_violations',
            'supervisor_evaluation', 'employment_years']

plt.figure(figsize=(12, 10))
for i, col in enumerate(bar_cols, 1):
    plt.subplot(2, 4, i)
    sns.barplot(x=df_quit[col].value_counts().index, y=df_quit[col].value_counts(normalize=True), data=df_quit)
    plt.title(col.capitalize(), fontsize=15)
    plt.xlabel('')
    plt.ylabel('Проценты')
    plt.xticks(rotation=20)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# **Портрет уволившегося сотрудника:**
#
# - стаж работы мене 2-х лет
#
# - зарплата таких сотрудников от 20-30 тысяч
#
# - в 90% случаев это специалисты уровня `junior`
#
# - имеют низкую или среднюю загруженность
#
# - 99% таких сотрудников не получили повышение за последний год
#
# - чаще получали оценку `удовлетворительно`

# %% [markdown]
# ### 3.3 Влияет ли уровень удовлетворенности работой сотрудника на его увольнение

# %% [markdown]
# Создадим общую таблицу из тестовых данных, куда добавим все целевые признаки

# %%
for_merge = test_features.merge(test_target_sat, on='id', how='inner')
test_merged = for_merge.merge(test_target_quit, on='id', how='inner')
test_merged.shape
# Out:
# (2000, 11)

# %% [markdown]
# Соединение прошло успешно

# %% [markdown]
# Посмотрим с помощью гистограммы насколько влияет удовлетворенность работой на увольнение сотрудника

# %% [markdown]
# Построение гистограммы:

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data=test_merged, x='job_satisfaction_rate', hue='quit', multiple='stack', color='skyblue', stat='density',
            common_norm=False)
plt.title('Удовлетворенность в разбивке по увольнению', fontsize=15)
plt.xlabel('Коэфициент удовлетворенности')
plt.ylabel('Плотность')
plt.show()

# %% [markdown]
# Посмотрим на распределение зарплаты в разбивке по `quit`

# %%
plt.figure(figsize=(8, 4))

sns.histplot(data=test_merged, x='salary', hue='quit', multiple='stack', stat='density', common_norm=False)
plt.title('Распределение зарплаты', fontsize=15)
plt.xlabel('Зарплата')
plt.ylabel('Плотность')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# Для большей достоверности проведем стастистический тест. Проверим, влияет ли уровень удовлетворенности на факт увольнения сотрудника:
# > Нулевая гипотеза **H0**: у оставшихся в компании сотрудников уровень удовлетворенности работой такой же, как и уволившихся сотрудников.
#
# > Альтернативная гипотеза **H1**: у оставшихся в компании сотрудников уровень удовлетворенности работой выше, чем у уволившихся сотрудников.

# %% [markdown]
# Для проведения статистического теста мы можем воспользоваться t-тестом для независимых выборок, так как анализируемые группы независимы друг от друга.

# %%
quit_yes = test_merged[test_merged['quit'] == 'yes']['job_satisfaction_rate']
quit_no = test_merged[test_merged['quit'] == 'no']['job_satisfaction_rate']

# Проведение t-теста
results = st.ttest_ind(quit_yes, quit_no, alternative='less', equal_var=False)

print(f"p-значение: {results.pvalue}")

alpha = 0.05
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу: уровень удовлетворенности работой у оставшихся сотрудников выше, чем уволившихся")
else:
    print("Принимаем нулевую гипотезу: уровень удовлетворенности работой у оставшихся и уволившихся сотрудников одинаковый")
# Out:
# p-значение: 1.3854314015771867e-101
# Отвергаем нулевую гипотезу: уровень удовлетворенности работой у оставшихся сотрудников выше, чем уволившихся

# %% [markdown]
# Статистический тест показал, что уровень удовлетворенности сотрудника влияет на факт его увольнения.

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# Как видно из графиков коэфициент удовлетворенности работой действительно влияет на то, уволится ли сотрудник или нет.
# У уволившихся сотрудников этот коэфициент значительно ниже.
#
# Так же у тех, кто уволился зарплата была достаточно низкой.

# %% [markdown]
# ## Шаг 4. Добавление нового входного признака

# %% [markdown]
# Добавим в новые тренировочные данные предсказание коэфициента удовлетворенности сотрудника.

# %%
train_quit['job_satisfaction_rate'] = best_model_sat.predict(train_quit.drop(['id', 'quit'], axis=1))
train_quit.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit  \
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no
#
#    job_satisfaction_rate
# 0               0.650000
# 1               0.823158
# 2               0.337500
# 3               0.350000
# 4               0.785000

# %% [markdown]
# ## Шаг 5. Подготовка данных

# %% [markdown]
# Создадим списки с категориальными и числовыми столбцами.

# %%
cat_cols_new = ['dept', 'last_year_promo', 'last_year_violations', 'supervisor_evaluation']

ord_cols_new = ['level', 'workload']

num_cols_new = ['salary', 'employment_years', 'job_satisfaction_rate']

label_column = 'quit'

# %% [markdown]
# Закодируем целевой признак с помощью LabelEncoder

# %%
label_encoder = LabelEncoder()

train_quit[label_column] = label_encoder.fit_transform(train_quit[label_column])
test_target_quit[label_column] = label_encoder.transform(test_target_quit[label_column])

# %% [markdown]
# Создадим пайплайны обработки данных

# %%
ohe_pipe_new = Pipeline(
    [
        ('imputing_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        ('ohe', OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')
        )
    ]
)

# %%
ord_pipe_new = Pipeline(
    [
        ('imputing_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        ('ord', OrdinalEncoder(categories= 
                               [
                                   ['junior', 'middle', 'senior'],
                                   ['low', 'medium', 'high']
                               ],
                               handle_unknown='use_encoded_value',
                               unknown_value=np.nan)
        ),
        ('imputing_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# %% [markdown]
# Соединим всё в препроцессор

# %%
data_preprocessor_new = ColumnTransformer(
    [
        ('ohe', ohe_pipe_new, cat_cols_new),
        ('ord', ord_pipe_new, ord_cols_new),
        ('num', StandardScaler(), num_cols_new)
    ],
    remainder='passthrough'
)

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 6. Обучение модели

# %% [markdown]
# Создадим финальный пайплайн с обработкой и моделью

# %%
pipe_final_new = Pipeline(
    [
        ('preprocessor', data_preprocessor_new),
        ('models', LogisticRegression(random_state=RANDOM_STATE))
    ]
)

# %% [markdown]
# Создадим сетку с моделями и их гиперпараметрами

# %%
param_grid_new = [
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE, max_iter=10000)],
        'models__solver': ['lbfgs', 'liblinear', 'sag'], # решатель модели
        'models__penalty': ['l1', 'l2'], # тип регуляризации
        'models__C': np.logspace(-4, 4, 20), # штрафы модели
        'preprocessor__num': [MinMaxScaler(), StandardScaler(), 'passthrough']
    },
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
#         'models__max_depth': range(2, 6),
        'models__max_features': range(2, 5),
        'models__min_samples_split': range(2, 11),
        'preprocessor__num': [MinMaxScaler(), StandardScaler(), 'passthrough']
    },
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(1, 150),
        'models__weights': ['uniform', 'distance'],
        'models__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'], # алгоритм вычислений
        'models__n_jobs': [-1],
        'preprocessor__num': [MinMaxScaler(), StandardScaler(), 'passthrough']
    }
]

# %% [markdown]
# Для перебора моделей будем использовать `RandomizedSearchCV`

# %% [markdown]
# В качестве метрики будем использовать ROC-AUC. Она подходит для несбалансированных классов.

# %%
randomized_search_new = RandomizedSearchCV(
    pipe_final_new,
    param_grid_new,
    scoring='roc_auc',
    cv=5,
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# %% [markdown]
# Обучим модель на тренировочных данных

# %%
randomized_search_new.fit(train_quit.drop(['id', 'quit'], axis=1), train_quit['quit'])
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('imputing_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %% [markdown]
# Выведем лучшую модель с параметрами и метрику при кросс-валидации

# %%
print('Лучшая модель и её параметры:\n\n', randomized_search_new.best_estimator_)
print ('Метрика лучшей модели при кросс-валидации:', randomized_search_new.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('imputing_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['dept', 'last_year_promo',
#                                                    'last_year_violations',
# ...

# %% [markdown]
# Добавим в тестовую выборку столбец с предсказанием коэфициента удовлетворенности работой

# %%
test_features_sorted_new['job_satisfaction_rate'] = best_model_sat.predict(test_features_sorted_new.drop('id', axis=1))

# %% [markdown]
# Сохраним лучшую модель и предскажем вероятности классов на тестовых данных

# %%
best_model_quit = randomized_search_new.best_estimator_
y_pred_quit = best_model_quit.predict_proba(test_features_sorted_new.drop('id', axis=1))

# %% [markdown]
# Выведем получившуюся метрику и округлим результат до 3-х знаков после запятой

# %%
roc_auc = round(roc_auc_score(test_target_quit_sorted.drop('id', axis=1), y_pred_quit[:, 1]), 3)
print(f'Метрика ROC-AUC на тестовых данных: {roc_auc}')
# Out:
# Метрика ROC-AUC на тестовых данных: 0.913

# %% [markdown]
# Проверим нашу модель на адекватность с помощью `DummyClassifier`. В качестве значения будем использовать **моду**

# %%
train_quit_preprocessed = pipe_final_new.named_steps['preprocessor'].fit_transform(train_quit.drop(['id', 'quit'], axis=1))
test_features_sorted_new = pipe_final_new.named_steps['preprocessor'].transform(test_features_sorted_new.drop(['id'], axis=1))

# %%
feature_names = pipe_final_new.named_steps['preprocessor'].get_feature_names_out()

# %%
train_quit_preprocessed = pd.DataFrame(train_quit_preprocessed, columns=feature_names)
test_features_sorted_new = pd.DataFrame(test_features_sorted_new, columns=feature_names)

# %%
dummy_clf = DummyClassifier(strategy='most_frequent')
dummy_clf.fit(train_quit_preprocessed, train_quit['quit'])

dummy_clf_pred = dummy_clf.predict_proba(test_features_sorted_new)

# %%
roc_auc = round(roc_auc_score(test_target_quit_sorted.drop('id', axis=1), dummy_clf_pred[:, 1]), 3)
print(f'Метрика ROC-AUC на тестовых данных: {roc_auc}')
# Out:
# Метрика ROC-AUC на тестовых данных: 0.5

# %% [markdown]
# **Вывод:**
#
# - Была проведена проверка модели на адекватность. Метрика константной модели составила **0.5**

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 7. Промежуточный вывод

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# Лучшей моделью оказался KNeighborsClassifier с гиперпараметрами:
#
# - algorithm='brute',
# - n_jobs=-1,
# - n_neighbors=109
#
# В качестве метрики был избран ROC-AUC, так как он подходит для работы с несбалансированными классами.
#
# Лучшая метркиа на тестовых данных составила **0.913**, модель уверенно предсказывает увольнение сотрудников
#
# - Была проведена проверка модели на адекватность. Метрика константной модели составила **0.5**

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# # Общий вывод
#
# ## Задача №1
#
# ### Предобработка данных
#
# - изменена орфография;
#
# - строки состоящие из пробелов были заменены на пропуски.
#
# - пропуски будут заполнены на этапе построения пайплайнов с помощью **SimpleImputer**
#
#
# ### Исследовательский анализ данных
#
# - распределение количества отработанных лет в компании выглядит логичным. Большинство сотрудников проработали в компании менее 4 лет. Медианное время - 3 года
#
# - распределение зарплаты скошено вправо. В среднем значение около 30 тысяч рублей. Максимальная зарплата 98400
#
# - распределение целевого признака равномерное. Наблюдаются пики в значениях 0.7 и 0.35
#
# - Самое большое количество сотрудников работает в отделе продаж. На втором месте отдел технологий. На третьем отдел покупок
#
# - Сотрудников уровня `junior` и `middle` поровну, а уровня `senior` в разы меньше
#
# - Большая часть сотрудников загружена средне
#
# - Всего 3% сотрудников получали повышение в последнем году
#
# - 16% сотрудников нарушали условия трудового договора за последний год
#
# - Начальник чаще всего ставит оценки `хорошо` и `удовлетворительно`
#
# - Гистограммы тестовых данных не различаются с тренировочными, соотношение примерно одинаковое
# - Распределение целевого признака тестовых данных такое же как и на тренировочных.
#
#
# ### Подготовка данных
#
# - созданы списки с категориальными данными (отдельно для ранжированных и неранжированных)
#
# - создан список числовых столбцов
#
# - созданы пайплайны предобработки данных и обьединены с помощью `ColumnTransformer`
#
# - создан общий пайплайн предобработки данных и моделью линейной регрессии
#
#
# ### Обучение модели
#
# - был построен пайплайн с обработкой данных. Для кодирования использовались `OneHotEncoder`и `OrdinalEncoder`. Для масштабирования были использованы `MinMaxScaler` и `StandardScaler`
#
# - была создана функция для рассчета метрики SMAPE
#
# - лучшей моделью оказался `DecisionTreeRegressor` с метрикой на тренировочной выборке при кросс-валидации **14.6** с гиперпараметрами:
#     - min_samples_leaf=3
#     - min_samples_split=5
#     - random_state=42
#
# - на тестовых данных метрика равна **13.8**
#
#
# Модель дерева решений справилась лучше, так как обладает более тонкой настройкой, из чего следует, что такая модель умеет улавливать более сложные зависимости, нежели простая Линейная регрессия.
#
#
# **Модель была проверена на адекватность с помощью DummyRegressor. Метрика при предсказании средним - **38.2****
#
# ---
#
# ## Задача №2
#
# ### Предобработка данных
#
# Была проведена предобработка данных:
#
# - исправлена орфография;
#
# - строковой целевой признак был заменен на числовые категории;
#
# - тестовая выборка отсортирована по `id`
#
#
# ### Исследовательский анализ данных
#
# **Выводы по всем данным:**
#
# - распределение отработанных в кампании лет выглядит логичным. Большинство сотрудников отработали 3 и менее года
#
# - распределение зарплаты скошено вправо. 75% сотрудников получают менее 75000
#
# - топ-3 по популярности отделов выглядит так: Отдел продаж, отдел разработки, отдел закупок
#
# - больше всего в компании сотрудников уровня `junior` и `middle`, `senior` намного меньше
#
# - большинство сотрудников имеют среднюю загруженность
#
# - больше 90% сотрудников не получали повышение за последний год
#
# - примерно 15% сотрудников нарушали условия трудового договора за последний год
#
# - чаще всего руководитель оценивает работу сотрудников на 4, чуть реже на 3
#
# - примерно 1/3 сотрудников покинуло компанию
#
# **Портрет уволившегося сотрудника:**
#
# - стаж работы мене 2-х лет
#
# - зарплата таких сотрудников от 20-30 тысяч
#
# - в 90% случаев это специалисты уровня `junior`
#
# - имеют низкую или среднюю загруженность
#
# - 99% таких сотрудников не получили повышение за последний год
#
# - чаще получали оценку `удовлетворительно`
#
#
# **Влияет ли удовлетворенность работой на увольнение:**
#
# - из графиков следует, что коэфициент удовлетворенности работой действительно влияет на то, уволится ли сотрудник или нет.
#
# - у уволившихся сотрудников этот коэфициент значительно ниже.
#
# - у уволившихся сотрудников зарплата была достаточно низкой.
#
#
# ### Подготовка данных
#
# - созданы списки с категориальными данными (отдельно для ранжированных и неранжированных)
#
# - создан список числовых столбцов
#
# - созданы пайплайны предобработки данных и обьединены с помощью `ColumnTransformer`
#
# - создан общий пайплайн предобработки данных и моделью логистической регрессии
#
#
# ### Обучение модели
#
# Были использованы 3 модели:
#
# - Логистическая регрессия
#
# - Метод ближайших соседей
#
# - Дерево решений
#
#
# Лучшей моделью оказался `KNeighborsClassifier` с гиперпараметрами:
#
# - algorithm='brute',
# - n_jobs=-1,
# - n_neighbors=109
#
# В качестве метрики был избран ROC-AUC, так как он подходит для работы с несбалансированными классами.
#
#
# Лучшая метркиа на тестовых данных составила **0.913**, модель уверенно предсказывает увольнение сотрудников
#
#
# **Модель была проверена на адекватность с помощью `DummyClassifier`. Метрика ROC-AUC составила *0.5***
#
# # Предложения для бизнеса.
#
#
#
# В первую очередь самым важным аспектом является заработная плата. Исходя из оценок руководителя, у уволившихся сотрудников это часто `удовлетворительно`. Возможно стоит ввести в компанию оплачиваемые стажировки, так бизнес будет терять меньше денег и сотрудники будут более качественно отобраны и с самого начала будут обучаться под нужды конкретной кампании.
#
# Так же сильно на увольнения влияет уровень удовлетворенности работой. Возможно стоит ввести дополнительные часы отдыха, сделать максимально комфортные условия для труда и чаще поощрять сотрудников премиями и интересными задачами, чтобы увеличить средний срок работы в кампании.
