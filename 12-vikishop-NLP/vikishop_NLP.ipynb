# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# # Описание задачи.
#
#
# Интернет-магазин **«Викишоп»** запускает новый сервис. Теперь пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. То есть клиенты предлагают свои правки и комментируют изменения других. Магазину нужен инструмент, который будет искать токсичные комментарии и отправлять их на модерацию.
#
# ---
#
# Обучите модель классифицировать комментарии на позитивные и негативные. В вашем распоряжении набор данных с разметкой о токсичности правок.
# Постройте модель со значением метрики качества **F1** не меньше **0.75**.
#
# ---
#
#
# # Описание данных
#
# Признаки:
#
#  - **text** - комментарии
#
#  - **toxic** - целевая переменная (0 - обычный комментарий, 1 - токсичный)
#
#
# ---
#
#
# # Моделирование
#
# Будем использовать несколько моделей:
#
#  - LogisticRegression в качестве бейзлайна
#
#  - RandomForestClassifier
#
#  - LightGBM
#
#
# В качестве метрики выступит **`F1`**

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\ilyal\anaconda3\lib\site-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: language-data>=1.2 in c:\users\ilyal\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\ilyal\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ilyal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ilyal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ilyal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ilyal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ilyal\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ilyal\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\ilyal\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\ilyal\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ilyal\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ilyal\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\ilyal\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\ilyal\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ilyal\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\ilyal\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ilyal\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ilyal\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ilyal\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --- ------------------------------------ 1.0/12.8 MB 3.6 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.8/12.8 MB 3.9 MB/s eta 0:00:03
#      --------- ------------------------------ 3.1/12.8 MB 4.5 MB/s eta 0:00:03
#      --------------- ------------------------ 5.0/12.8 MB 5.7 MB/s eta 0:00:02
#      -------------------- ------------------- 6.6/12.8 MB 6.0 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.6/12.8 MB 5.9 MB/s eta 0:00:01
#      -------------------------- ------------- 8.4/12.8 MB 5.5 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.8 MB 5.3 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.8 MB 5.5 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 6.0 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\ilyal\anaconda3\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ilyal\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: language-data>=1.2 in c:\users\ilyal\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\ilyal\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ilyal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ilyal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ilyal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ilyal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ilyal\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ilyal\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\ilyal\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\ilyal\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ilyal\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ilyal\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\ilyal\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\ilyal\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ilyal\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\ilyal\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ilyal\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ilyal\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ilyal\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.0)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd 
import numpy as np 
import re
import time

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import f1_score, make_scorer
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import spacy

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline


from tqdm.notebook import tqdm 


tqdm.pandas()

# %%
start_time = time.time()

# %% [markdown]
# Загрузим данные

# %%
try:
    df = pd.read_csv(r"C:\Users\ilyal\OneDrive\Рабочий стол\Портфолио\practicum_projects\vikishop_NLP_12\toxic_comments.csv")
    
except:
    df = pd.read_csv(r"/datasets/toxic_comments.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                               text  toxic
# 0           0  Explanation\nWhy the edits made under my usern...      0
# 1           1  D'aww! He matches this background colour I'm s...      0
# 2           2  Hey man, I'm really not trying to edit war. It...      0
# 3           3  "\nMore\nI can't make any real suggestions on ...      0
# 4           4  You, sir, are my hero. Any chance you remember...      0

# %% [markdown]
# Выведем информацию о датафрейме

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159292 entries, 0 to 159291
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  159292 non-null  int64
#  1   text        159292 non-null  object
#  2   toxic       159292 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.6+ MB

# %% [markdown]
# Проверим датафрейм на наличие явных дубликатов

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Сразу посмотрим присутствует ли дисбаланс классов

# %%
df.toxic.value_counts()
# Out:
# toxic
# 0    143106
# 1     16186
# Name: count, dtype: int64

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# ### Промежуточный вывод.
#
#  - были загружены данные
#
#  - пропусков и дубликатов в датафрейме нет
#
#  - присутствует явный дисбаланс классов
#
#  - в текстах присутствуют переносы строк, ссылки, email-адреса, различные символы, аббревиатуры и цифры

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 2. Обработка данных

# %% [markdown]
# Создадим функцию, которая с помощью регулярных выражений будет убирать из текста переносы строк, ссылки, адреса электронной почты, различные символы, аббревиатуры и цифры

# %%
def clean_text(text):
    text = text.replace('\n', ' ')  # удаление новых строк
    # удаление ссылок
    text = re.sub(r'http\S+', '', text) 
    text = re.sub(r'www\.\S+', '', text)
    text = re.sub(r'\S+@\S+\.\S+', '', text) # удаление email адресов
    text = re.sub(r'[^a-zA-Z]', ' ', text)  # оставляем только латинские буквы
    text = text.lower()  # приведение к нижнему регистру
    text = text.replace('utc', ' ') # удаление аббревиатуры
    return text

# %% [markdown]
# Применим функцию к тексту

# %%
df['cleaned_text'] = df['text'].apply(clean_text)

# %%
df.sample(5)
# Out:
#         Unnamed: 0                                               text  toxic  \
# 47885        47940  "\nThe point is that it's already been covered...      0
# 55849        55910  OK, the first human I have found. I want to co...      0
# 29644        29683  Looking through the cites the Qualudes id refe...      0
# 105682      105779  The MOS covers a lot of material and im not qu...      0
# 99744        99841  No need to kick them where they are down. Your...      0
#
#                                              cleaned_text
# 47885     the point is that it s already been covered ...
# 55849   ok  the first human i have found  i want to co...
# 29644   looking through the cites the qualudes id refe...
# 105682  the mos covers a lot of material and im not qu...
# 99744   no need to kick them where they are down  your...

# %% [markdown]
# Преобразование прошло успешно

# %% [markdown]
# Теперь проведем токенизацию, лемматизацию (приведение слов к их изначальной форме), а так же удалим стоп-слова

# %%
# Загрузка модели English для SpaCy
nlp = spacy.load("en_core_web_sm")

def lem_tok_text(text):
    # Приводим текст к нижнему регистру
    text = text.lower()
    
    # Обработка текста с помощью SpaCy
    doc = nlp(text)
    
    # Удаление стоп-слов и лемматизация
    lemmatized_tokens = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
    
    # Возвращаем строку из лемматизированных слов
    return ' '.join(lemmatized_tokens)

# %% [markdown]
# Применим функцию к "чистому тексту"

# %%
df['processed_text'] = df['cleaned_text'].progress_apply(lem_tok_text)
# Out:
#   0%|          | 0/159292 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#    Unnamed: 0                                               text  toxic  \
# 0           0  Explanation\nWhy the edits made under my usern...      0
# 1           1  D'aww! He matches this background colour I'm s...      0
# 2           2  Hey man, I'm really not trying to edit war. It...      0
# 3           3  "\nMore\nI can't make any real suggestions on ...      0
# 4           4  You, sir, are my hero. Any chance you remember...      0
#
#                                         cleaned_text  \
# 0  explanation why the edits made under my userna...
# 1  d aww  he matches this background colour i m s...
# 2  hey man  i m really not trying to edit war  it...
# 3    more i can t make any real suggestions on im...
# 4  you  sir  are my hero  any chance you remember...
#
#                                       processed_text
# 0  explanation edit username hardcore metallica f...
# 1  d aww   match background colour m seemingly st...
# 2  hey man   m try edit war   s guy constantly re...
# 3     t real suggestion improvement    wonder sec...
# 4                sir   hero   chance remember page s

# %% [markdown]
# Преобразование прошло успешно

# %% [markdown]
# Проведем повторную проверку на наличие явных дубликатов после лемматизации

# %%
df['processed_text'].duplicated().sum()
# Out:
# 726

# %% [markdown]
# Удалим дубликаты

# %%
df = df.drop_duplicates(subset='processed_text')

# %%
df['processed_text'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Так же необходимо убрать из текста все сокращенные названия месяцев

# %%
months_short = r'\b(jan|feb|mar|apr|may|jun|jul|aug|sep|oct|nov|dec)\b'

def remove_months(text):
    return re.sub(months_short, '', text)

# применим функцию
df['processed_text'] = df['processed_text'].apply(remove_months)

# %% [markdown]
# Теперь проведем векторизацию текстов, для этого будем использовать TfidfVectorizer

# %% [markdown]
# Для этого сразу разделим данные на обучающую и тестовую выборки

# %%
X_train, X_test, y_train, y_test = train_test_split(df['processed_text'],
                                                    df['toxic'],
                                                    test_size=0.1, 
                                                    random_state=42)

# %%
tfidf = TfidfVectorizer(max_features=5000)

X_train = tfidf.fit_transform(X_train)
X_test = tfidf.transform(X_test)

print(f'Размер обучающей выборки {X_train.shape[0]} строк и {X_train.shape[1]} признаков')
print(f'Размер тестовой выборки {X_test.shape[0]} строк и {X_test.shape[1]} признаков')
# Out:
# Размер обучающей выборки 142709 строк и 5000 признаков
# Размер тестовой выборки 15857 строк и 5000 признаков

# %%
type(X_train)
# Out:
# scipy.sparse._csr.csr_matrix

# %% [markdown]
# Преобразование прошло успешно

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# ## Промежуточный вывод
#
#  - были созданы функции для очистки текста с помощью регулярных выражений
#
#  - была проведена лемматизация текста
#
#  - были удалены явные дубликаты, появившиеся после лемматизации
#
#  - было проведено разделение данных на тренировочную и тестовую выборки
#
#  - была проведена векторизация текста с помощью TfidfVectorizer

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 3.Обучение моделей

# %% [markdown]
# Проверим, влияет ли балансировка классов на метрику. Для балансировки будем использовать SMOTE

# %% [markdown]
# ### Обучение с балансировкой

# %% [markdown]
# Создадим пайплайн imblearn, в качестве бейзлайна будем использовать Логистичесукю Регрессию

# %%
pipeline = Pipeline([
    ('smote', SMOTE()),
    ('model_lr', LogisticRegression(max_iter=1000))
])

param_grid = {
    'model_lr__C': [0.001, 0.01, 0.1, 1, 10],
    'model_lr__solver': ['liblinear', 'lbfgs']
}

# %% [markdown]
# Инициализируем SKFold и разобьем данные на 5 слоев со стратификацией

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# Скопируем метрику F1 для использования в поиске по сетке

# %%
f1_scorer = make_scorer(f1_score)

# %% [markdown]
# Инициализируем поиск по сетке

# %%
gs_bal = GridSearchCV(pipeline,
                  param_grid,
                  scoring=f1_scorer,
                  cv=skf,
                  verbose=1)

# %% [markdown]
# Обучим поиск по сетке

# %%
# %%time 
gs_bal.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# CPU times: total: 4min 47s
# Wall time: 3min 16s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('smote', SMOTE()),
#                                        ('model_lr',
#                                         LogisticRegression(max_iter=1000))]),
#              param_grid={'model_lr__C': [0.001, 0.01, 0.1, 1, 10],
#                          'model_lr__solver': ['liblinear', 'lbfgs']},
#              scoring=make_scorer(f1_score, response_method='predict'),
#              verbose=1)

# %%
gs_bal.best_score_
# Out:
# 0.6656547042758059

# %% [markdown]
# Как видно, метрика с балансировкой сильно ниже пороговой

# %% [markdown]
# ---

# %% [markdown]
# ### Обучение без балансировки

# %% [markdown]
# Теперь запустим поиск по сетке без балансировки

# %%
pipeline = Pipeline([
    ('model_lr', LogisticRegression(max_iter=1000))
])

param_grid = {
    'model_lr__C': [0.001, 0.01, 0.1, 1, 10],
    'model_lr__solver': ['liblinear', 'lbfgs']
}

# %%
gs = GridSearchCV(pipeline,
                  param_grid,
                  scoring=f1_scorer,
                  cv=skf,
                  verbose=1)

# %%
# %%time
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# CPU times: total: 54.4 s
# Wall time: 18.1 s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('model_lr',
#                                         LogisticRegression(max_iter=1000))]),
#              param_grid={'model_lr__C': [0.001, 0.01, 0.1, 1, 10],
#                          'model_lr__solver': ['liblinear', 'lbfgs']},
#              scoring=make_scorer(f1_score, response_method='predict'),
#              verbose=1)

# %%
gs.best_score_
# Out:
# 0.773868432705538

# %% [markdown]
# Так стало намного лучше

# %% [markdown]
# ### В дальнейшем не будем балансировать классы

# %% [markdown]
# ---

# %% [markdown]
# Теперь обучим модели и подберем гиперпараметры

# %%
pipeline_final = Pipeline([
    ('model', LogisticRegression(max_iter=1000))
])

# %% [markdown]
# Список моделей и их гиперпараметров для перебора

# %%
param_grid_final = [
    {
        'model': [LogisticRegression(max_iter=1000)],
        'model__C': [0.01, 0.1, 1, 5, 10],
        'model__solver': ['liblinear', 'lbfgs']
    },
    {
        'model': [RandomForestClassifier(random_state=42)],
        'model__n_estimators': [200, 300],
        'model__max_depth': [None, 10],
        'model__min_samples_split': [2, 5, 10]
    },
    {
        'model': [lgb.LGBMClassifier(random_state=42)],
        'model__n_estimators': [50, 100, 200],
        'model__learning_rate': [0.01, 0.1, 0.02],
        'model__max_depth': [-1, 10, 20]
    }
]

# %% [markdown]
# Создание стратифицированных фолдов. Будем делать 3 разбиения, чтобы сократить время обучения моделей

# %%
cv = StratifiedKFold(n_splits=3,
                     shuffle=True,
                     random_state=42)

# %% [markdown]
# Инициализация поиска по сетке

# %%
gs_final = GridSearchCV(pipeline_final,
                        param_grid_final,
                        cv=cv,
                        scoring=f1_scorer,
                        n_jobs=-1)

# %% [markdown]
# Подбор лучших параметров

# %%
# %%time 
gs_final.fit(X_train, y_train)
# Out:
# C:\Users\ilyal\anaconda3\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# CPU times: total: 4.69 s
# Wall time: 50min 8s
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('model',
#                                         LogisticRegression(max_iter=1000))]),
#              n_jobs=-1,
#              param_grid=[{'model': [LogisticRegression(max_iter=1000)],
#                           'model__C': [0.01, 0.1, 1, 5, 10],
#                           'model__solver': ['liblinear', 'lbfgs']},
#                          {'model': [RandomForestClassifier(random_state=42)],
#                           'model__max_depth': [None, 10],
#                           'model__min_samples_split': [2, 5, 10],
#                           'model__n_estimators': [200, 300]},
#                          {'model': [LGBMClassifier(random_state=42)],
#                           'model__learning_rate': [0.01, 0.1, 0.02],
#                           'model__max_depth': [-1, 10, 20],
#                           'model__n_estimators': [50, 100, 200]}],
#              scoring=make_scorer(f1_score, response_method='predict'))

# %% [markdown]
# Выведем лучшую метрику с кросс-валидации

# %%
gs_final.best_score_
# Out:
# 0.7732309767827078

# %% [markdown]
# Выведем лучшую модель

# %%
gs_final.best_params_
# Out:
# {'model': LogisticRegression(max_iter=1000),
#  'model__C': 10,
#  'model__solver': 'lbfgs'}

# %% [markdown]
# Сохраним результаты кросс-валидации в датафрейм

# %%
res = pd.DataFrame(gs_final.cv_results_)

# %% [markdown]
# Выведем топ-10 моделей и их метрики

# %%
res[['param_model', 'rank_test_score', 'mean_test_score']].sort_values(by='rank_test_score').reset_index(drop=True).head(10)
# Out:
#                                param_model  rank_test_score  mean_test_score
# 0        LogisticRegression(max_iter=1000)                1         0.773231
# 1        LogisticRegression(max_iter=1000)                2         0.769795
# 2        LogisticRegression(max_iter=1000)                3         0.769357
# 3        LogisticRegression(max_iter=1000)                4         0.767881
# 4          LGBMClassifier(random_state=42)                5         0.762453
# 5  RandomForestClassifier(random_state=42)                6         0.762127
# 6  RandomForestClassifier(random_state=42)                7         0.761860
# 7  RandomForestClassifier(random_state=42)                8         0.761375
# 8  RandomForestClassifier(random_state=42)                9         0.761297
# 9  RandomForestClassifier(random_state=42)               10         0.761069

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# ## Промежуточный вывод
#
#  - было проверено влияние дисбаланса классов на модель
#
#  - был сделан вывод о том, что в балансировке классов нет необходимости, достаточно стратификации при обучении
#
#  - были обучены 3 модели на кросс-валидации, лучшую метрику показала Логистическая регрессия **`0.773`**

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 4. Предсказание

# %% [markdown]
# Инициализируем лучшую модель и сделаем предсказание на тестовой выборке

# %%
model = LogisticRegression(solver='lbfgs', C=10, max_iter=1000)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print(f'F1 score for LogisticRegression: {f1_score(y_test, y_pred)}')
# Out:
# F1 score for LogisticRegression: 0.7761398697291738

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# ## Промежуточный вывод
#
# Было выполнено предсказание на тестовых данных с помощью LogisticRegression, метрика составила **`0.776`**

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#D2DCFA; padding:10px;">
#
# # Финальный вывод
#
# ---
#
# ### Загрузка данных
#
#  - были загружены данные
#
#  - пропусков и дубликатов в датафрейме нет
#
#  - присутствует явный дисбаланс классов
#
#  - в текстах присутствуют переносы строк, ссылки, email-адреса, различные символы, аббревиатуры и цифры
#
# ---
#
# ### Предобработка данных
#
#  - были созданы функции для очистки текста с помощью регулярных выражений
#
#  - была проведена лемматизация текста
#
#  - были удалены явные дубликаты, появившиеся после лемматизации
#
#  - было проведено разделение данных на тренировочную и тестовую выборки
#
#  - была проведена векторизация текста с помощью TfidfVectorizer
#
# ---
#
# ### Обучение моделей
#
#  - было проверено влияние дисбаланса классов на модель
#
#  - был сделан вывод о том, что в балансировке классов нет необходимости, достаточно стратификации при обучении
#
#  - были обучены 3 модели на кросс-валидации, лучшую метрику показала Логистическая регрессия **`0.773`**
#
# ---
#
# ### Предсказание на тестовых данных
#
# Было выполнено предсказание на тестовых данных с помощью LogisticRegression, метрика составила **`0.776`**
#
# ---
#
# ### Реккомендации
#
# Исходя из результатов исследования я бы рекомендовал к выбору именно Логистическую регрессию. Её главное преимущество по сравнению с другими моделями  в том, что она тратит в десятки раз меньше времени на обучение. При этом в данном случае, с предоставленными комментариями, с данными параметрами моделей, Логистическая регрессия показывает метрику F1 выше всех.

# %%
end_time = time.time()
print(end_time - start_time)
# Out:
# 5064.382776737213
